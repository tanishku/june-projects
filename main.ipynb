# %% [markdown]
# # Stanford Open Policing
# Check [README](README.md) for details

# %%
import geopandas as gpd
from matplotlib import pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('data/az_mesa_2023_01_26.csv')
df.head()
# Out:
#    raw_row_number        date      time                     location  \
# 0               1  2014-01-01  05:04:00     700 E FRANKLIN AVE, MESA
# 1               2  2014-01-01  12:33:00         400 E BROWN RD, MESA
# 2               3  2014-01-01  12:27:00    3600 E SOUTHERN AVE, MESA
# 3               4  2014-01-01  13:52:00        400 N CENTER ST, MESA
# 4               5  2014-01-01  03:02:00  2100 W UNIVERSITY0 DR, MESA
#
#          lat         lng geocode_source  subject_age subject_race subject_sex  \
# 0  33.402381 -111.816143             GM         36.0     hispanic      female
# 1  33.435577 -111.822654             GM         58.0        white      female
# 2  33.393701 -111.753798             GM         19.0        white        male
# 3  33.422339 -111.831445             GM         46.0        black        male
# 4  33.422121 -111.876371             GM         27.0        white        male
#
#   officer_id_hash       type                                     violation  \
# ...

# %%
gf = gpd.read_file('data/az_mesa_shapefiles/MesaBeats.shp')
gf.head()
# Out:
#    ESZ_NUM DISTRICT                                           geometry
# 0       35   CENTRL  POLYGON ((711989.286 881074.789, 712023.63 881...
# 1       36   CENTRL  POLYGON ((723485.867 893111.907, 723483.37 892...
# 2       31   CENTRL  POLYGON ((709821.816 878451.881, 710258.037 87...
# 3       13   FIESTA  POLYGON ((708712.528 875797.693, 709006.93 875...
# 4       32   CENTRL  POLYGON ((723512.776 875930.537, 723395.613 87...

# %%
print(len(df), len(gf), df.columns, sep = '\n')
